# %%
f = open('ТПУ_389.txt', "r", encoding="utf-8")
text = f.read()
import string
text = text.lower()
spec_chars = string.punctuation + '\n\xa0«»\t—...' #небольшие дополнения к пунктуации библиотеки string

# %%
text = "".join([ch for ch in text if ch not in spec_chars]) #перебираем текст, т.е убираем пунктуацию
text = "".join([ch for ch in text if ch not in string.digits])  #убираем числа

# %%
# !pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from nltk import word_tokenize
from nltk import download
download ('punkt')
download ('stopwords')
from nltk.corpus import stopwords
stopwords = stopwords.words('russian')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk import word_tokenize 
text_tokens = word_tokenize(text) #токенизируем текст

# %%
# !pip install pymorphy2
from pymorphy2 import MorphAnalyzer
morph = MorphAnalyzer()
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
words_lemmatized = []
for word in text_tokens:
    result = morph.parse(word)
    most_probable_result = result[0] ## почему мы берем первый разбор? см.в этом месте: https://pymorphy2.readthedocs.io/en/latest/user/guide.html#select-correct
    normal_form = most_probable_result.normal_form
    words_lemmatized.append(normal_form)

# %%
import nltk
text_nltk = nltk.Text(words_lemmatized) #класс нлтк.текст
from nltk.probability import FreqDist #библиотека для статистики
fdist = FreqDist(text_nltk) #кортеж

# %%
fdist.most_common(15)

# %%
fdist.plot(30,cumulative=False)

# %%
from collections import Counter #добавляем библио
freq_bigramms = Counter(nltk.ngrams(text_tokens, 2)) #разбираем на биграмм

# %%
text2 = nltk.Text(freq_bigramms.most_common(20)) #делаем из биграмм текст (У нас какой-то список)

# %%
import pandas as pd
b = [[text, fdist.most_common(15), text2]]
b_df = pd.DataFrame(b,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
#
#                                             Биграммы
# 0  (((неразрушающего, контроля), 5), ((ученые, тп...

# %%
#def dobavtabl(text)
c = [[text, fdist.most_common(15), text2]]
c_df = pd.DataFrame(c,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df = b_df.append(c_df)
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
# 0  актуальные задачи современной химической науки...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
# 0  [(и, 26), (в, 15), (химия, 9), (молекулярный, ...
#
#                                             Биграммы
# 0  (((неразрушающего, контроля), 5), ((ученые, тп...
# 0  (((молекулярных, машин), 4), ((института, хими...

# %%
d = [[text, fdist.most_common(15), text2]]
d_df = pd.DataFrame(d,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df = b_df.append(d_df)
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
# 0  актуальные задачи современной химической науки...
# 0  в томском политехническом университете в рамка...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
# 0  [(и, 26), (в, 15), (химия, 9), (молекулярный, ...
# 0  [(и, 16), (в, 10), (на, 6), (конкурс, 5), (эне...
#
#                                             Биграммы
# 0  (((неразрушающего, контроля), 5), ((ученые, тп...
# 0  (((молекулярных, машин), 4), ((института, хими...
# 0  (((разработки, продукции), 2), ((продукции, и)...

# %%
e = [[text, fdist.most_common(15), text2]]
e_df = pd.DataFrame(e,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df = b_df.append(e_df)
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
# 0  актуальные задачи современной химической науки...
# 0  в томском политехническом университете в рамка...
# 0  ученые томского политеха получили нековалентны...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
# 0  [(и, 26), (в, 15), (химия, 9), (молекулярный, ...
# 0  [(и, 16), (в, 10), (на, 6), (конкурс, 5), (эне...
# 0  [(и, 11), (в, 10), (каркас, 8), (соль, 8), (ор...
#
#                                             Биграммы
# 0  (((неразрушающего, контроля), 5), ((ученые, тп...
# 0  (((молекулярных, машин), 4), ((института, хими...
# 0  (((разработки, продукции), 2), ((продукции, и)...
# 0  (((иодониевые, соли), 3), ((исследовательской,...

# %%
f = [[text, fdist.most_common(15), text2]]
f_df = pd.DataFrame(f,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df = b_df.append(f_df)
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
# 0  актуальные задачи современной химической науки...
# 0  в томском политехническом университете в рамка...
# 0  ученые томского политеха получили нековалентны...
# 0  в томском политехе начала работу xxiii междуна...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
# 0  [(и, 26), (в, 15), (химия, 9), (молекулярный, ...
# 0  [(и, 16), (в, 10), (на, 6), (конкурс, 5), (эне...
# 0  [(и, 11), (в, 10), (каркас, 8), (соль, 8), (ор...
# 0  [(в, 14), (и, 14), (конференция, 10), (год, 5)...
#
#                                             Биграммы
# 0  (((неразрушающего, контроля), 5), ((ученые, тп...
# 0  (((молекулярных, машин), 4), ((института, хими...
# 0  (((разработки, продукции), 2), ((продукции, и)...
# 0  (((иодониевые, соли), 3), ((исследовательской,...
# 0  (((в, томском), 2), ((химия, и), 2), ((и, хими...

# %%
g = [[text, fdist.most_common(15), text2]]
g_df = pd.DataFrame(g,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df = b_df.append(g_df)
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
# 0  актуальные задачи современной химической науки...
# 0  в томском политехническом университете в рамка...
# 0  ученые томского политеха получили нековалентны...
# 0  в томском политехе начала работу xxiii междуна...
# 0  в томском политехническом университете в понед...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
# 0  [(и, 26), (в, 15), (химия, 9), (молекулярный, ...
# 0  [(и, 16), (в, 10), (на, 6), (конкурс, 5), (эне...
# 0  [(и, 11), (в, 10), (каркас, 8), (соль, 8), (ор...
# 0  [(в, 14), (и, 14), (конференция, 10), (год, 5)...
# 0  [(и, 22), (в, 17), (конференция, 15), (химичес...
#
#                                             Биграммы
# 0  (((неразрушающего, контроля), 5), ((ученые, тп...
# 0  (((молекулярных, машин), 4), ((института, хими...
# 0  (((разработки, продукции), 2), ((продукции, и)...
# ...

# %%
h = [[text, fdist.most_common(15), text2]]
h_df = pd.DataFrame(h,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df = b_df.append(h_df)
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
# 0  актуальные задачи современной химической науки...
# 0  в томском политехническом университете в рамка...
# 0  ученые томского политеха получили нековалентны...
# 0  в томском политехе начала работу xxiii междуна...
# 0  в томском политехническом университете в понед...
# 0  сотрудники центра хериотватт томского политехн...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
# 0  [(и, 26), (в, 15), (химия, 9), (молекулярный, ...
# 0  [(и, 16), (в, 10), (на, 6), (конкурс, 5), (эне...
# 0  [(и, 11), (в, 10), (каркас, 8), (соль, 8), (ор...
# 0  [(в, 14), (и, 14), (конференция, 10), (год, 5)...
# 0  [(и, 22), (в, 17), (конференция, 15), (химичес...
# 0  [(в, 11), (и, 10), (быть, 8), (аналог, 7), (ме...
#
#                                             Биграммы
# 0  (((неразрушающего, контроля), 5), ((ученые, тп...
# ...

# %%
i = [[text, fdist.most_common(15), text2]]
i_df = pd.DataFrame(i,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df = b_df.append(i_df)
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
# 0  актуальные задачи современной химической науки...
# 0  в томском политехническом университете в рамка...
# 0  ученые томского политеха получили нековалентны...
# 0  в томском политехе начала работу xxiii междуна...
# 0  в томском политехническом университете в понед...
# 0  сотрудники центра хериотватт томского политехн...
# 0  ученые тпу разработали экологически чистый спо...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
# 0  [(и, 26), (в, 15), (химия, 9), (молекулярный, ...
# 0  [(и, 16), (в, 10), (на, 6), (конкурс, 5), (эне...
# 0  [(и, 11), (в, 10), (каркас, 8), (соль, 8), (ор...
# 0  [(в, 14), (и, 14), (конференция, 10), (год, 5)...
# 0  [(и, 22), (в, 17), (конференция, 15), (химичес...
# 0  [(в, 11), (и, 10), (быть, 8), (аналог, 7), (ме...
# 0  [(и, 5), (отход, 5), (углеводород, 4), (учёный...
#
# ...

# %%
j = [[text, fdist.most_common(15), text2]]
j_df = pd.DataFrame(j,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df = b_df.append(j_df)
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
# 0  актуальные задачи современной химической науки...
# 0  в томском политехническом университете в рамка...
# 0  ученые томского политеха получили нековалентны...
# 0  в томском политехе начала работу xxiii междуна...
# 0  в томском политехническом университете в понед...
# 0  сотрудники центра хериотватт томского политехн...
# 0  ученые тпу разработали экологически чистый спо...
# 0  ученые томского политехнического университета ...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
# 0  [(и, 26), (в, 15), (химия, 9), (молекулярный, ...
# 0  [(и, 16), (в, 10), (на, 6), (конкурс, 5), (эне...
# 0  [(и, 11), (в, 10), (каркас, 8), (соль, 8), (ор...
# 0  [(в, 14), (и, 14), (конференция, 10), (год, 5)...
# 0  [(и, 22), (в, 17), (конференция, 15), (химичес...
# 0  [(в, 11), (и, 10), (быть, 8), (аналог, 7), (ме...
# ...

# %%
k = [[text, fdist.most_common(15), text2]]
k_df = pd.DataFrame(k,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df = b_df.append(k_df)
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
# 0  актуальные задачи современной химической науки...
# 0  в томском политехническом университете в рамка...
# 0  ученые томского политеха получили нековалентны...
# 0  в томском политехе начала работу xxiii междуна...
# 0  в томском политехническом университете в понед...
# 0  сотрудники центра хериотватт томского политехн...
# 0  ученые тпу разработали экологически чистый спо...
# 0  ученые томского политехнического университета ...
# 0  в москве состоялось совместное заседание научн...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
# 0  [(и, 26), (в, 15), (химия, 9), (молекулярный, ...
# 0  [(и, 16), (в, 10), (на, 6), (конкурс, 5), (эне...
# 0  [(и, 11), (в, 10), (каркас, 8), (соль, 8), (ор...
# 0  [(в, 14), (и, 14), (конференция, 10), (год, 5)...
# 0  [(и, 22), (в, 17), (конференция, 15), (химичес...
# ...

# %%
l = [[text, fdist.most_common(15), text2]]
l_df = pd.DataFrame(l,  columns=['Текст', 'Ключевые слова', 'Биграммы']) 
b_df = b_df.append(l_df)
b_df
# Out:
#                                                Текст  \
# 0  ученые тпу разрабатывают универсальный комплек...
# 0  актуальные задачи современной химической науки...
# 0  в томском политехническом университете в рамка...
# 0  ученые томского политеха получили нековалентны...
# 0  в томском политехе начала работу xxiii междуна...
# 0  в томском политехническом университете в понед...
# 0  сотрудники центра хериотватт томского политехн...
# 0  ученые тпу разработали экологически чистый спо...
# 0  ученые томского политехнического университета ...
# 0  в москве состоялось совместное заседание научн...
# 0  исследователи томского политеха совместно с ко...
#
#                                       Ключевые слова  \
# 0  [(в, 16), (контроль, 11), (и, 10), (метод, 7),...
# 0  [(и, 26), (в, 15), (химия, 9), (молекулярный, ...
# 0  [(и, 16), (в, 10), (на, 6), (конкурс, 5), (эне...
# 0  [(и, 11), (в, 10), (каркас, 8), (соль, 8), (ор...
# 0  [(в, 14), (и, 14), (конференция, 10), (год, 5)...
# ...

# %%
b_df.to_excel('ТПУ_данные.xlsx')
